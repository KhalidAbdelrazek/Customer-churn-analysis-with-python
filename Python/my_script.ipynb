# %% [markdown]
# ## Task 1: Understand the Dataset
#
# ### 🎯 Description
# In this task, we will familiarize ourselves with the dataset by loading it, exploring the first few rows, identifying data types, and checking for missing values.
#
# ### 🛠️ Steps
# 1. Load the dataset using **pandas**.
# 2. Display the first 10 rows.
# 3. Identify the data types of each column.
# 4. Check for missing values.
#
# ### 💻 Code Example
# ```python
# import pandas as pd
#
# # Step 1: Load the dataset
# # Replace 'data.csv' with the actual dataset file name
# df = pd.read_csv("data.csv")
#
# # Step 2: Display the first 10 rows
# print("First 10 rows of the dataset:\n")
# print(df.head(10))
#
# # Step 3: Identify data types of each column
# print("\nData types of each column:\n")
# print(df.dtypes)
#
# # Step 4: Check for missing values
# print("\nMissing values in each column:\n")
# print(df.isnull().sum())

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

figures_dir = "../figures"
os.makedirs(figures_dir, exist_ok=True)

# %%
path = "E:\\Data Analysis\\Saiket\\Project 1\\Data\\Telco_Customer_Churn_Dataset.csv"
df_original = pd.read_csv(path)
df_original
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df = df_original.copy()

print("First 10 rows of the dataset:")
print(df.head(10))
# Out:
# First 10 rows of the dataset:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
print("\nData types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # 🧹 Task 2: Data Cleaning
#
# ## 🎯 Objective
# Ensure the dataset is clean, consistent, and ready for further analysis by:
# - Handling missing values (fill, drop, or impute).
# - Removing duplicate records.
# - Standardizing column names for consistency.
#
# ---
#
# ## 🛠 Steps & Code
#
# ```python
# # Step 1: Remove duplicate records
# df.drop_duplicates(inplace=True)
#
# # Step 2: Standardize column names
# df.columns = (
#     df.columns
#       .str.strip()           # remove leading/trailing spaces
#       .str.lower()           # convert to lowercase
#       .str.replace(" ", "_") # replace spaces with underscores
# )
#
# # Step 3: Quick Check
# print("✅ Missing values after cleaning:\n", df.isnull().sum())
# print("\n✅ Dataset shape after removing duplicates:", df.shape)
# print("\n✅ Standardized column names:\n", df.columns.tolist())

# %%
# Remove duplicate records
df = df.drop_duplicates() 

# Verify cleaning
print("\nAfter cleaning:")
print("Data types:\n", df.dtypes)
print("\nMissing values:\n", df.isnull().sum())
print("\nDuplicates:", df.duplicated().sum())
print("\nSample cleaned data:\n", df.head(5))
# Out:
# After cleaning:
# Data types:
#  customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object
#
# Missing values:
#  customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# ...

# %%
# put underscore between words in column names (TechSupport -> Tech_Support)
df.columns = df.columns.str.replace('([a-z])([A-Z])', r'\1_\2',regex=True).str.lower()
# df.columns = df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'internet_service',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges', 'churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# # 📊 Task 3: Exploratory Data Analysis (EDA)
#
# ## 🎯 Objective
# Explore the dataset to understand trends, distributions, and relationships between variables.
# Key goals:
# - Generate summary statistics (mean, median, mode).
# - Visualize numerical columns using histograms and box plots.
# - Analyze churn rates (proportion of churn vs. non-churn).
#
# ---
#
# ## 📌 Steps
# 1. **Generate Summary Statistics**
#    - Calculate measures like mean, median, and mode.
#    - Review data spread (standard deviation, min, max, quartiles).
#
# 2. **Visualize Numerical Columns**
#    - Use histograms and KDE plots to understand data distribution.
#    - Use box plots to detect outliers and compare distributions.
#
# 3. **Analyze Churn Rates**
#    - Compare churn vs. non-churn proportions.
#    - Visualize counts and percentages to highlight imbalance (if any).
#
# ---
#
# ## 📌 Expected Outcome
# - Clear overview of dataset characteristics.
# - Insights into central tendency and data variability.
# - Identification of skewed distributions and potential outliers.
# - Understanding of churn proportions to guide further analysis.
#
# ---
#
# ## 🧑‍💻 Skills Applied
# - Statistical analysis
# - Data visualization
# - Exploratory data analysis
#
# ---
#
# ## 🛠 Tools Used
# - **Pandas** → For summary statistics
# - **Seaborn** → For histograms, box plots, count plots
# - **Matplotlib** → For plot customization and labeling

# %%
# Convert to correct data types
df['customer_id'] = df['customer_id'].astype(str)
df['senior_citizen'] = df['senior_citizen'].astype(bool)
df['partner'] = df['partner'].astype(bool)
df['dependents'] = df['dependents'].astype(bool)
df['phone_service'] = df['phone_service'].astype(bool)
df['tenure'] = df['tenure'].astype(int)
df['monthly_charges'] = df['monthly_charges'].astype(float)
df['churn'] = df['churn'].astype(float)
df['total_charges'] = pd.to_numeric(df['total_charges'], errors='coerce')

# Convert categorical columns
categorical_cols = [
    'gender','multiple_lines',
    'internet_service','online_security','online_backup','device_protection',
    'tech_support','streaming_tv','streaming_movies','contract',
    'paperless_billing','payment_method'
]

df[categorical_cols] = df[categorical_cols].astype('category')

# Check dtypes
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 9
#       7 df['tenure'] = df['tenure'].astype(int)
#       8 df['monthly_charges'] = df['monthly_charges'].astype(float)
# ----> 9 df['churn'] = df['churn'].astype(float)
#      10 df['total_charges'] = pd.to_numeric(df['total_charges'], errors='coerce')
#      12 # Convert categorical columns
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
print("Summary statistics (numerical columns):\n")
print(df.describe())
# Out:
# Summary statistics (numerical columns):
#
#        senior_citizen       tenure  monthly_charges  total_charges
# count     7043.000000  7043.000000      7043.000000    7032.000000
# mean         0.162147    32.371149        64.761692    2283.300441
# std          0.368612    24.559481        30.090047    2266.771362
# min          0.000000     0.000000        18.250000      18.800000
# 25%          0.000000     9.000000        35.500000     401.450000
# 50%          0.000000    29.000000        70.350000    1397.475000
# 75%          0.000000    55.000000        89.850000    3794.737500
# max          1.000000    72.000000       118.750000    8684.800000

# %%
print("\nMedian values:\n", df.median(numeric_only=True))
print("\nMode values:\n", df.mode().iloc[0])
# Out:
# Median values:
#  senior_citizen        0.000
# tenure               29.000
# monthly_charges      70.350
# total_charges      1397.475
# dtype: float64
#
# Mode values:
#  customer_id                0002-ORFBO
# gender                           Male
# senior_citizen                    0.0
# partner                            No
# dependents                         No
# tenure                            1.0
# phone_service                     Yes
# multiple_lines                     No
# internet_service          Fiber optic
# online_security                    No
# online_backup                      No
# device_protection                  No
# tech_support                       No
# streaming_tv                       No
# streaming_movies                   No
# contract               Month-to-month
# paperless_billing                 Yes
# payment_method       Electronic check
# monthly_charges                 20.05
# total_charges                    20.2
# ...

# %%
numerical_cols = ['tenure', 'monthly_charges', 'total_charges']

for col in numerical_cols :
    # bins = np.arange(min(df[col]), max(df[col]) + 1)
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=50)
    plt.title(f'Distribution of {col.capitalize().replace("_", " ")}')
    plt.xlabel(col.capitalize().replace("_", " "))
    plt.ylabel('Frequency')
    plt.savefig(os.path.join(figures_dir, f"distribution_of_{col}.png"), dpi=300)
    plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(6,4))
    plt.boxplot(df[col])
    plt.title(f'Box plot of {col.capitalize().replace("_", " ")}')
    plt.xlabel(col.capitalize().replace("_", " "))
    plt.ylabel('Value')
    plt.savefig(os.path.join(figures_dir, f"boxplot_{col}.png"), dpi=300)
    plt.show()

# %%
plt.figure(figsize=(5,4))
ax = sns.countplot(data=df, x='churn', palette="Set2")
plt.title("Churn vs Non-Churn Count")
plt.xlabel("Churn")
plt.ylabel("frequency")


for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom')

plt.savefig(os.path.join(figures_dir, "churn_count.png"), dpi=300)
plt.show()
# Out:
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\1818165537.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='churn', palette="Set2")

# %%
# Proportion of churn
churn_rate = df['churn'].value_counts(normalize=True) * 100
print("\nChurn Rate (%):\n", churn_rate)
# Out:
# Churn Rate (%):
#  churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# Step 5: Numerical variables vs Churn
for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x='churn', y=col, data=df, palette="Set2")
    plt.title(f"{col.capitalize().replace('_', ' ')} vs Churn")
    plt.xlabel("Churn")
    plt.ylabel(col.capitalize().replace('_', ' '))
    plt.savefig(os.path.join(figures_dir, f"churn_by_{col}.png"), dpi=300)
    plt.show()
# Out:
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\3146675125.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y=col, data=df, palette="Set2")
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\3146675125.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y=col, data=df, palette="Set2")
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\3146675125.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='churn', y=col, data=df, palette="Set2")

# %%
# mean vs median of numerical cols
for col in numerical_cols:
    mean_val = df[col].mean()
    median_val = df[col].median()
    print(f"{col} - Mean: {mean_val:.2f}, Median: {median_val:.2f}")
# Out:
# tenure - Mean: 32.37, Median: 29.00
# monthly_charges - Mean: 64.76, Median: 70.35
# total_charges - Mean: 2283.30, Median: 1397.47

# %%
# total charges outliers count
q1 = df['total_charges'].quantile(0.25)
q3 = df['total_charges'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = df[(df['total_charges'] < lower_bound) | (df['total_charges'] > upper_bound)]
print(f"\nNumber of outliers in 'total_charges': {outliers.shape[0]}")
print(outliers[['customer_id', 'total_charges']])
print(f"q1: {q1}, q3: {q3}, iqr: {iqr}, lower_bound: {lower_bound}, upper_bound: {upper_bound}")
print(f"Min total_charges: {df['total_charges'].min()}, Max total_charges: {df['total_charges'].max()}")
# Out:
# Number of outliers in 'total_charges': 0
# Empty DataFrame
# Columns: [customer_id, total_charges]
# Index: []
# q1: 401.45, q3: 3794.7375, iqr: 3393.2875000000004, lower_bound: -4688.481250000001, upper_bound: 8884.66875
# Min total_charges: 18.8, Max total_charges: 8684.8

# %%
# percentile threshold
threshold = df['total_charges'].quantile(0.99)

# distribution of total_charges with threshold line
top_customers = df[df['total_charges'] >= threshold]


plt.figure(figsize=(6,4))
sns.histplot(df['total_charges'], kde=True, bins=50, color='blue', label='Total Charges')
plt.axvline(threshold, color='red', linestyle='--', label='99th Percentile Threshold')
plt.xlabel('Total Charges')
plt.title('Distribution of Total Charges with 99th Percentile Threshold')
plt.ylabel('Frequency')
plt.legend()
plt.savefig(os.path.join(figures_dir, "churn_by_total_charges.png"), dpi=300)
plt.show()

print(f"Threshold (99th percentile): {threshold}")
print(f"Number of customers in top 1%: {top_customers.shape[0]}")
print(top_customers[['customer_id', 'total_charges']].sort_values(by='total_charges', ascending=False).head(10))
# Out:
# Threshold (99th percentile): 8039.882999999997
# Number of customers in top 1%: 71
#      customer_id  total_charges
# 4610  2889-FPWRM        8684.80
# 4586  7569-NMZYQ        8672.45
# 6768  9739-JLPQJ        8670.10
# 5347  9788-HNGUT        8594.40
# 2187  8879-XUAHX        8564.75
# 6118  9924-JPRMC        8547.15
# 5558  0675-NCDYU        8543.25
# 2368  6650-BWFRT        8529.50
# 2603  0164-APGRB        8496.70
# 2025  1488-PBLJN        8477.70

# %% [markdown]
# # 🎯 Task 4: Customer Segmentation Visualization
#
# ## 📌 Objective
# Visualize customer distribution and analyze differences in monthly charges across different tenure categories.
# Key goals:
# - Segment customers based on tenure (e.g., 0–12 months, 13–36 months, 37+ months).
# - Use **pie/donut charts** to illustrate customer proportions across these segments.
# - Use **clustered bar charts** to compare average monthly charges for each tenure group.
# - Add annotations to highlight significant insights and trends.
#
# ---
#
# ## 📌 Steps
# 1. **Define Tenure Categories**
#    - Create groups based on customer tenure:
#      - **0–12 months**
#      - **13–36 months**
#      - **37+ months**
#
# 2. **Pie/Donut Chart for Distribution**
#    - Visualize customer proportions across tenure categories.
#    - Show relative size of each group to highlight customer base composition.
#
# 3. **Clustered Bar Chart for Monthly Charges**
#    - Compare average monthly charges across tenure groups.
#    - Highlight differences with annotations (e.g., highest spending group).
#
# 4. **Add Interactivity (Optional with Plotly)**
#    - Enable hover tooltips for values.
#    - Allow zooming and filtering for deeper exploration.
#
# ---
#
# ## 📌 Expected Outcome
# - **Pie/Donut Chart** → Clear representation of how customers are distributed by tenure.
# - **Clustered Bar Chart** → Comparison of average monthly charges by tenure group, highlighting significant differences.
# - **Annotations** → Easy-to-spot insights about customer behavior (e.g., newer customers paying more).
#
# ---
#
# ## 🧑‍💻 Skills Applied
# - Customer segmentation
# - Data visualization
# - Highlighting trends with annotations
# - Interactive visualization design
#
# ---
#
# ## 🛠 Tools Used
# - **Matplotlib** → For static pie and bar charts
# - **Plotly** → For interactive and dynamic visualizations

# %%
import plotly.express as px

# Create tenure categories
def categorize_tenure(months):
    if months <= 12:
        return "0-12 months"
    elif months <= 36:
        return "13-36 months"
    else:
        return "37+ months"

df["tenure_group"] = df["tenure"].apply(categorize_tenure)
df[["tenure", "tenure_group"]].head()
# Out:
#    tenure  tenure_group
# 0       1   0-12 months
# 1      34  13-36 months
# 2       2   0-12 months
# 3      45    37+ months
# 4       2   0-12 months

# %%
# Step 2: Pie/Donut chart for customer distribution
tenure_counts = df["tenure_group"].value_counts()

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(
    tenure_counts,
    labels=tenure_counts.index,
    autopct="%1.1f%%",
    startangle=90,
    wedgeprops=dict(width=0.4)  # makes it a donut chart
)
ax.set_title("Customer Distribution by Tenure Group")
plt.savefig(os.path.join(figures_dir, "churn_by_tenure_group.png"), dpi=300)
plt.show()

# %%
# Clustered bar chart for average monthly charges by tenure group
avg_charges = df.groupby("tenure_group")["monthly_charges"].mean().reset_index()

fig = px.bar(
    avg_charges,
    x="tenure_group",
    y="monthly_charges",
    text="monthly_charges",
    color="tenure_group",
    title="Average Monthly Charges by Tenure Group"
)
fig.update_traces(texttemplate='%{text:.2f}', textposition="outside")
plt.savefig(os.path.join(figures_dir, "churn_by_tenure_group.png"), dpi=300)
fig.show()

# %% [markdown]
# # Task 5: Advanced Analysis
#
# ## 📌 Description
# This task focuses on performing deeper customer analytics by exploring relationships between **tenure, charges, churn, and demographics**. The goal is to uncover hidden patterns that explain churn behavior and customer lifecycle trends.
#
# ## 🎯 Objectives
# - Group customers by **tenure** to compute statistics for charges and churn.
# - Analyze churn rates across **demographics**:
#   - Gender
#   - Senior citizen status
#   - Payment methods
#   - Contract types
# - Visualize **trends over time** (if applicable) to identify lifecycle patterns.
# - Provide actionable insights to guide retention strategies.
#
# ## 🛠️ Skills Practiced
# - **Data Grouping**: Aggregating data by categories such as tenure, gender, and contract type.
# - **Statistical Analysis**: Calculating churn proportions, averages, and distributions.
# - **Data Visualization**: Using plots to compare churn and non-churn segments.
# - **Demographic Analysis**: Identifying high-risk groups by customer attributes.
# - **Comparative Analysis**: Understanding differences in churn between categories.
#
# ## 📊 Tools
# - **Pandas** – for grouping, aggregating, and calculating statistics.
# - **Matplotlib / Seaborn** – for static visualizations.
# - **Plotly** – for interactive exploration of churn trends.

# %%
# ---- Grouping by tenure to compute statistics ----
tenure_stats = df.groupby('tenure').agg(
    avg_monthly_charges=('monthly_charges', 'mean'),
    avg_total_charges=('total_charges', 'mean'),
    churn_rate=('churn', lambda x: (x == 'Yes').mean())
).reset_index()

print("Tenure Statistics:\n", tenure_stats.head())

plt.figure(figsize=(8, 4))
sns.lineplot(data=tenure_stats, x='tenure', y='churn_rate', marker="o")
plt.title("Churn Rate by Tenure")
plt.xlabel("Tenure (months)")
plt.ylabel("Churn Rate")
plt.savefig(os.path.join(figures_dir, "churn_by_tenure.png"), dpi=300)
plt.show()
# Out:
# Tenure Statistics:
#     tenure  avg_monthly_charges  avg_total_charges  churn_rate
# 0       0            41.418182                NaN    0.000000
# 1       1            50.485808          50.485808    0.619902
# 2       2            57.206303         114.332353    0.516807
# 3       3            58.015000         174.690000    0.470000
# 4       4            57.432670         230.530682    0.471591

# %%
demographic_cols = ['gender', 'senior_citizen', 'payment_method', 'contract']

for col in demographic_cols:
    churn_rates = (
        df.groupby(col)['churn']
        .value_counts(normalize=True)
        .unstack()
        .fillna(0)[['No', 'Yes']]  # force order
    )
    
    ax = churn_rates.plot(
        kind='bar', 
        stacked=True, 
        figsize=(6,4), 
        color=['#66c2a5', '#fc8d62']
    )
    
    plt.title(f"Churn Rate by {col.capitalize().replace('_',' ')}")
    plt.ylabel("Proportion")
    plt.xlabel(col.capitalize().replace('_',' '))
    plt.legend(title="Churn", loc="upper right")
    plt.savefig(os.path.join(figures_dir, f"churn_by_{col}.png"), dpi=300)
    plt.show()
# Out:
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\3286036494.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\3286036494.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# C:\Users\khali\AppData\Local\Temp\ipykernel_14892\3286036494.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
# ---- Lifecycle / contract type analysis ----
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x='contract', y='monthly_charges', hue='churn', palette="Set2")
plt.title("Monthly Charges by Contract Type and Churn")
plt.xlabel("Contract Type")
plt.ylabel("Monthly Charges")
plt.legend(title="Churn")
plt.savefig(os.path.join(figures_dir, "churn_by_contract.png"), dpi=300)
plt.show()

# %%
# relations between churn and {phone_service, multiple_lines, internet_service, online_security, online_backup, device_protection, tech_support, streaming_tv, streaming_movies}
for col in ['phone_service', 'multiple_lines', 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies']:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col, hue='churn', palette="Set2")
    plt.title(f"{col} vs Churn")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.legend(title="Churn", loc="upper right")
    plt.savefig(os.path.join(figures_dir, f"churn_by_{col}.png"), dpi=300)
    plt.show()

# %%
# Features to plot
features = [
    'phone_service', 'multiple_lines', 'internet_service',
    'online_security', 'online_backup', 'device_protection',
    'tech_support', 'streaming_tv', 'streaming_movies'
]

# Set up grid (3 rows x 3 cols for 9 features)
fig, axes = plt.subplots(3, 3, figsize=(18, 12))
axes = axes.flatten()

# Loop over features & plot on subplots
for i, col in enumerate(features):
    sns.countplot(data=df, x=col, hue='churn', palette="Set2", ax=axes[i])
    axes[i].set_title(f"{col} vs Churn")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")
    axes[i].legend(title="Churn", loc="upper right")

# Adjust layout
plt.tight_layout()

# Save as one figure
plt.savefig(os.path.join(figures_dir, "churn_by_services.png"), dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Churn counts
churn_counts = df['churn'].value_counts()
labels = churn_counts.index
sizes = churn_counts.values

# Custom format: percent + count
def autopct_format(pct, all_vals):
    absolute = int(round(pct/100.*sum(all_vals)))
    return f"{pct:.1f}% ({absolute})"

# Plot
plt.figure(figsize=(8, 8))
wedges, texts, autotexts = plt.pie(
    sizes,
    labels=None,  # hide labels on slices
    autopct=lambda pct: autopct_format(pct, sizes),
    startangle=90,
    colors=['#66c2a5', '#fc8d62'],
    wedgeprops=dict(width=0.4),
    pctdistance=1.2,   # place values outside
)

# Style the percentage+count labels
for autotext in autotexts:
    autotext.set_fontsize(11)
    autotext.set_color("black")
    autotext.set_weight("normal")

# Add legend
plt.legend(
    wedges, labels,
    title="Churn Status",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1),
    fontsize=12
)

# Title
plt.title("Customer Churn Distribution", fontsize=16, pad=20)
# save figure 
plt.savefig(
    os.path.join(figures_dir, "churn_distribution_pie_chart.png"),
    dpi=500,
    bbox_inches="tight"   # ensures legend & title are included
)
plt.show()

# %%
# 📊 Visual Suggestion: Side-by-side bar charts (e.g., churn vs. non-churn for each demographic/service factor).
# in one photo

features = ['gender', 'senior_citizen', 'contract', 'payment_method']

for col in features:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col, hue='churn', palette=['#66c2a5', '#fc8d62'])
    plt.title(f'Churn by {col}')
    plt.xlabel(col)
    plt.ylabel("Customer Count")
    plt.legend(title="Churn", labels=["No", "Yes"])
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
